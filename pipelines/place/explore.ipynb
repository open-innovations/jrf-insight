# %%
from loaders import load_geojson

# %%
load_geojson('ua22').plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../../data/geo/ua22.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 load_geojson('ua22').plot()
#
# File /media/data/code/oi/jrf-insight/pipelines/place/loaders.py:12, in load_geojson(type)
#      10 path = f'{DATA_DIR}/geo/{type}.geojson'
#      11 key = type.upper() + 'CD'
# ---> 12 data = gpd.read_file(path)
#      13 if type == 'panrgn22':
#      14     key = 'RGN21CD'
#
# ...

# %%
load_geojson('cty22').plot()
# Out:
# <Axes: >
