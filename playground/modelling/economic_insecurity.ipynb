# %% [markdown]
# ### `The concept`
# Different statistics are normalised in the range 0-1 and then mean averaged. A score of 0 corresponds to something less likely to cause poverty (e.g. extremely low rate  of unemployment).
#
# The highest and lowest values will score 1 and 0, respectively, and everything else will fall somewhere in between. We do this across 6 metrics for economic insecurity and their average score is taken.
#
# These metrics are: economic inactivity, unemployment, mean weekly wage, median weekly wage, claimants as a proportion of residents aged 16-64 and proportion of households that are fuel poor. In the interest of simplicity, each metric has equal weighting.
#
# ### `Assumptions/Disclaimers`
# Where data is unavailable, the default is to use the value for the parent (containing) geography. For example, if Leeds had missing data then the value for Yorkshire & the Humber would be used.
#
# When the final average is calculated, if the data is for a given statistic is unavailable, that statistic does not contribute to the index score. We drop rows that have fewer than 3 values. This is to avoid places getting an index score with too few data points contributing to the average.
#
# In general, it shouldn't be the case that geographies at the same level could have different statistics contributing to the index score. The output csv file contains a list of the metrics that were per place.
#
# Finally, this is a proof of concept. The aim of this model is not to create a new measure of poverty, but to see how different places rank relative to eachother across a range of different metrics. We are testing out new ways of combining different datasets to provide useful insights. The results of this model should not be seen as a measure of poverty or taken at absolute face value.

# %% [markdown]
# ### Notes
# - We want to create a simple normalisation algorithm for our modelling.
# - We will map highest/lowest values for a category from 0-1. (Or, we could normalise to average value of containing geography.)
# - Then calculate a mean average.
# - Easy to add weights in if necessary.
# - We will say that 0 = least likely to cause poverty (e.g. low house price to wage ratio) and 1 = most likely to cause poverty (e.g. high rate of unemployment).

# %% [markdown]
# For a set $$X$$ of values containing $$x_i$$ individual values, the normalised values
# $$x_{normalised} = \frac{x_i - X_{min}}{X_{max}-X_{min}}$$

# %%
import os
import pandas as pd
import numpy as np
os.chdir(r"C:\Users\LukeStrange\Code\jrf-insight")

# %% [markdown]
# Load the geography lookup tree

# %%
geography_tree = pd.read_csv('data/geo/geography_tree.csv', usecols=['parent', 'child'])
geography_tree.describe()
# Out:
#            parent      child
# count        1646       1646
# unique         86       1644
# top     E06000057  E05014284
# freq           66          2

# %% [markdown]
# Define several functions:
# - `transform_data` attempts to reshape the data into a consitent format. It gets the most recent date's value per geography.
# - `pivot_and_concatenate_dataframes` - pivots the frames to have one variable per column and geo_codes as the index.
# - `fill_gaps_parent_value` - fills any NaN values with the parent value, if it exists.
# - `normalise` - normalises the values from 0-1 (with 1 corresponding to something more likely to cause poverty)
# -  `which_variables` - determine which variables (non-NaNs) were used to calculate the score.

# %%
def transform_data(data, variable_name):
    '''
    Select a given variable from the dataset.
    Get the most recent date per geography using idxmax(). 
    **Requires date format to be pandas datetime**.
    '''
    assert isinstance(variable_name, str), 'Variable name must be type: str'
    try:
        filtered_data = data[data.variable_name == variable_name].copy()
    except:
        return print('The variable', variable_name, 'is not present in the data.')
    try:
        filtered_data['date'] = pd.to_datetime(filtered_data['date'])
    except:
        return print('Cannot convet date column to pandas datetime.')
    filtered_data = filtered_data.loc[filtered_data.groupby(['geography_code'])[
        'date'].idxmax()]
    # only using necessary columns
    filtered_data = filtered_data.loc[:, [
        'date', 'geography_code', 'geography_name', 'variable_name', 'value']].set_index('date')
    return filtered_data

# %%
def pivot_and_concatenate_dataframes(dataframes):
    '''
    Pivot the frames into a wide format and concatenate
    them into a single dataframe.
    '''
    pivoted_frames = []
    for frame in dataframes:
        colnames = frame.columns.to_list()
        assert 'geography_code' in colnames
        assert 'value' in colnames
        assert 'variable_name' in colnames
        pivoted_frames.append(frame.pivot(index='geography_code', columns='variable_name', values='value'))
    result = pd.concat(pivoted_frames, axis=1)
    return result

# %%
def fill_gaps_parent_value(data, lookup):
    ''' 
    Fill any data gaps with the value of the parent, 
    if it exists.
    '''
    # copy the frame so we don't later the thing we iterate over
    data_copy = data.copy()
    for col in data.columns.to_list():
        na_rows = data[data.isnull().any(axis=1)]
        for i, row in na_rows.iterrows():
            try:
                parent_code = lookup[lookup.child == row.name]['parent'].values[0]
            except:
                print('No parent found for', row.name, 'for the variable', col)
                continue
            # if the parent isn't present in the geo tree, go to the next row with na values.
            parents_value = data[data.index == parent_code][col].iloc[0]
            #print(parent_code, parents_value)
            data_copy.at[i, col] = parents_value

    return data_copy

# %%
def normalise(data, highest_score_causes_poverty):
    '''
    Takes the range of values and maps the max/min
    to 0-1. A value of 1 means something is more likely
    to cause poverty. This would correspond to 
    highest_score_cause_poverty == True.
    '''
    variable_names = data.columns.to_list()
    assert len(variable_names) == len(highest_score_causes_poverty), 'Length of highest_score_cause_poverty does not match the number of variables'
    normalised_columns = []
    if 'geography_code' in variable_names:
        variable_names.remove('geography_code')
    if 'date' in variable_names:
        variable_names.remove('date')
    i = 0
    for variable in variable_names:
        mx, mn = data[f'{variable}'].max(), data[f'{variable}'].min()
        range = mx - mn 
        if highest_score_causes_poverty[i] == True:
            data[f'Normalised {variable}'] = (data[f'{variable}'] - mn) / range
        else:
            data[f'Normalised {variable}'] = abs((data[f'{variable}'] - mx) / range)
        normalised_columns.append(f'Normalised {variable}')
        i += 1
    data['mean_normalised_score'] = data[normalised_columns].mean(axis=1)
    
    return data

# %%
# Read data
labour_market = pd.read_csv('data/labour-market/labour-market.csv')
weekly_earnings = pd.read_csv('data/ashe/weekly-earnings.csv')
claimants = pd.read_csv('data/claimant-count/claimant-count.csv')
fuel_poverty = pd.read_csv('data/fuel-poverty/fuel-poverty.csv')

# %%
# Get the individual variables as their own dataframes
economic_inactivity = transform_data(labour_market, '% who are economically inactive - aged 16-64')
unemployment = transform_data(labour_market, 'Unemployment rate - aged 16-64')
mean_weekly_wage = transform_data(weekly_earnings, 'mean_weekly_wage')
median_weekly_wage = transform_data(weekly_earnings, 'median_weekly_wage')
claimants = transform_data(claimants, 'Claimants as a proportion of residents aged 16-64')
fuel_poverty = transform_data(fuel_poverty, 'Proportion of households fuel poor (%)')

variable_key = {
    '% who are economically inactive - aged 16-64': '1',
    'Unemployment rate - aged 16-64': '2',
    'mean_weekly_wage': '3',
    'median_weekly_wage': '4',
    'Claimants as a proportion of residents aged 16-64': '5',
    'Proportion of households fuel poor (%)': '6'
}

# %%
# Pivot concatenate the dataframes
data = pivot_and_concatenate_dataframes([economic_inactivity, unemployment, mean_weekly_wage, median_weekly_wage, claimants, fuel_poverty])

# %%
# Fill the gaps where possible
data = fill_gaps_parent_value(data, geography_tree)

# we drop rows that have fewer than 3 values. This is to avoid places getting an index score with too few data points contributing to the avrage.
data = data.dropna(thresh=3)
# Out:
# No parent found for E11000001 for the variable % who are economically inactive - aged 16-64
# No parent found for E11000002 for the variable % who are economically inactive - aged 16-64
# No parent found for E11000003 for the variable % who are economically inactive - aged 16-64
# No parent found for E11000006 for the variable % who are economically inactive - aged 16-64
# No parent found for E11000007 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000670 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000671 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000672 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000673 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000674 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000675 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000676 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000677 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000678 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000679 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000680 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000681 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000682 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000683 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000684 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000685 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000686 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000739 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000740 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000741 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000742 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000743 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000744 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000745 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000746 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000747 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000748 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000749 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000750 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000751 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000752 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000753 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000754 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000755 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000756 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000757 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000758 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000916 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000917 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000918 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000919 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000920 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000921 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000922 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000923 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000924 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000925 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000926 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000927 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000928 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000929 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000930 for the variable % who are economically inactive - aged 16-64
# No parent found for E05000931 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003145 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003146 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003147 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003148 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003149 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003150 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003151 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003152 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003153 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003154 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003155 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003156 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003157 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003205 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003206 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003207 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003208 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003209 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003210 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003211 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003212 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003213 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003214 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003215 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003216 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003217 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003218 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003219 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003220 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003221 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003222 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003223 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003224 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003225 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003226 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003227 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003228 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003229 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003230 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003231 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003232 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003233 for the variable % who are economically inactive - aged 16-64
# No parent found for E05003234 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006191 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006198 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006203 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006206 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006297 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006298 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006299 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006300 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006301 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006302 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006303 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006304 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006305 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006306 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006307 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006308 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006309 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006310 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006311 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006312 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006313 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006314 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006315 for the variable % who are economically inactive - aged 16-64
# No parent found for E05006316 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009664 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009665 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009666 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009667 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009668 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009669 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009670 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009671 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009672 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009673 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009674 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009675 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009676 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009677 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009678 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009679 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009680 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009681 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009682 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009683 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009684 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009685 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009686 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009687 for the variable % who are economically inactive - aged 16-64
# No parent found for E05009688 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010044 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010045 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010046 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010047 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010048 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010049 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010050 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010051 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010052 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010053 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010054 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010055 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010056 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010057 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010058 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010059 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010060 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010061 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010062 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010774 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010775 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010776 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010777 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010778 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010779 for the variable % who are economically inactive - aged 16-64
# No parent found for E05010780 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011308 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011309 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011310 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011311 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011312 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011313 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011314 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011315 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011316 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011317 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011318 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011319 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011320 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011321 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011322 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011323 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011324 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011325 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011326 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011327 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011328 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011329 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011330 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011331 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011332 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011333 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011334 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011335 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011336 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011337 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011338 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011339 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011340 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011341 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011342 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011343 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011344 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011345 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011346 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011347 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011490 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011491 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011492 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011493 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011494 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011495 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011496 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011497 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011498 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011499 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011500 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011501 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011502 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011503 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011504 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011505 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011506 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011507 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011720 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011721 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011722 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011723 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011724 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011725 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011726 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011727 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011728 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011729 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011730 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011731 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011732 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011733 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011734 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011735 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011736 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011737 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011738 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011739 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011740 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011741 for the variable % who are economically inactive - aged 16-64
# No parent found for E05011742 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012356 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012357 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012358 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012359 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012360 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012361 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012362 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012363 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012364 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012365 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012366 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012367 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012368 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012369 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012370 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012371 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012372 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012373 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012374 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012375 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012376 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012377 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012378 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012379 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012380 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012381 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012382 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012383 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012384 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012385 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012386 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012387 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012388 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012389 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012390 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012391 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012548 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012549 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012550 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012551 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012552 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012553 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012554 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012555 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012556 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012557 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012558 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012559 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012560 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012561 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012562 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012563 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012564 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012940 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012941 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012942 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012943 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012944 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012945 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012946 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012947 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012948 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012949 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012950 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012951 for the variable % who are economically inactive - aged 16-64
# No parent found for E05012952 for the variable % who are economically inactive - aged 16-64
# No parent found for E11000001 for the variable Unemployment rate - aged 16-64
# No parent found for E11000002 for the variable Unemployment rate - aged 16-64
# No parent found for E11000003 for the variable Unemployment rate - aged 16-64
# No parent found for E11000006 for the variable Unemployment rate - aged 16-64
# No parent found for E11000007 for the variable Unemployment rate - aged 16-64
# No parent found for E05000670 for the variable Unemployment rate - aged 16-64
# No parent found for E05000671 for the variable Unemployment rate - aged 16-64
# No parent found for E05000672 for the variable Unemployment rate - aged 16-64
# No parent found for E05000673 for the variable Unemployment rate - aged 16-64
# No parent found for E05000674 for the variable Unemployment rate - aged 16-64
# No parent found for E05000675 for the variable Unemployment rate - aged 16-64
# No parent found for E05000676 for the variable Unemployment rate - aged 16-64
# No parent found for E05000677 for the variable Unemployment rate - aged 16-64
# No parent found for E05000678 for the variable Unemployment rate - aged 16-64
# No parent found for E05000679 for the variable Unemployment rate - aged 16-64
# No parent found for E05000680 for the variable Unemployment rate - aged 16-64
# No parent found for E05000681 for the variable Unemployment rate - aged 16-64
# No parent found for E05000682 for the variable Unemployment rate - aged 16-64
# No parent found for E05000683 for the variable Unemployment rate - aged 16-64
# No parent found for E05000684 for the variable Unemployment rate - aged 16-64
# No parent found for E05000685 for the variable Unemployment rate - aged 16-64
# No parent found for E05000686 for the variable Unemployment rate - aged 16-64
# No parent found for E05000739 for the variable Unemployment rate - aged 16-64
# No parent found for E05000740 for the variable Unemployment rate - aged 16-64
# No parent found for E05000741 for the variable Unemployment rate - aged 16-64
# No parent found for E05000742 for the variable Unemployment rate - aged 16-64
# No parent found for E05000743 for the variable Unemployment rate - aged 16-64
# No parent found for E05000744 for the variable Unemployment rate - aged 16-64
# No parent found for E05000745 for the variable Unemployment rate - aged 16-64
# No parent found for E05000746 for the variable Unemployment rate - aged 16-64
# No parent found for E05000747 for the variable Unemployment rate - aged 16-64
# No parent found for E05000748 for the variable Unemployment rate - aged 16-64
# No parent found for E05000749 for the variable Unemployment rate - aged 16-64
# No parent found for E05000750 for the variable Unemployment rate - aged 16-64
# No parent found for E05000751 for the variable Unemployment rate - aged 16-64
# No parent found for E05000752 for the variable Unemployment rate - aged 16-64
# No parent found for E05000753 for the variable Unemployment rate - aged 16-64
# No parent found for E05000754 for the variable Unemployment rate - aged 16-64
# No parent found for E05000755 for the variable Unemployment rate - aged 16-64
# No parent found for E05000756 for the variable Unemployment rate - aged 16-64
# No parent found for E05000757 for the variable Unemployment rate - aged 16-64
# No parent found for E05000758 for the variable Unemployment rate - aged 16-64
# No parent found for E05000916 for the variable Unemployment rate - aged 16-64
# No parent found for E05000917 for the variable Unemployment rate - aged 16-64
# No parent found for E05000918 for the variable Unemployment rate - aged 16-64
# No parent found for E05000919 for the variable Unemployment rate - aged 16-64
# No parent found for E05000920 for the variable Unemployment rate - aged 16-64
# No parent found for E05000921 for the variable Unemployment rate - aged 16-64
# No parent found for E05000922 for the variable Unemployment rate - aged 16-64
# No parent found for E05000923 for the variable Unemployment rate - aged 16-64
# No parent found for E05000924 for the variable Unemployment rate - aged 16-64
# No parent found for E05000925 for the variable Unemployment rate - aged 16-64
# No parent found for E05000926 for the variable Unemployment rate - aged 16-64
# No parent found for E05000927 for the variable Unemployment rate - aged 16-64
# No parent found for E05000928 for the variable Unemployment rate - aged 16-64
# No parent found for E05000929 for the variable Unemployment rate - aged 16-64
# No parent found for E05000930 for the variable Unemployment rate - aged 16-64
# No parent found for E05000931 for the variable Unemployment rate - aged 16-64
# No parent found for E05003145 for the variable Unemployment rate - aged 16-64
# No parent found for E05003146 for the variable Unemployment rate - aged 16-64
# No parent found for E05003147 for the variable Unemployment rate - aged 16-64
# No parent found for E05003148 for the variable Unemployment rate - aged 16-64
# No parent found for E05003149 for the variable Unemployment rate - aged 16-64
# No parent found for E05003150 for the variable Unemployment rate - aged 16-64
# No parent found for E05003151 for the variable Unemployment rate - aged 16-64
# No parent found for E05003152 for the variable Unemployment rate - aged 16-64
# No parent found for E05003153 for the variable Unemployment rate - aged 16-64
# No parent found for E05003154 for the variable Unemployment rate - aged 16-64
# No parent found for E05003155 for the variable Unemployment rate - aged 16-64
# No parent found for E05003156 for the variable Unemployment rate - aged 16-64
# No parent found for E05003157 for the variable Unemployment rate - aged 16-64
# No parent found for E05003205 for the variable Unemployment rate - aged 16-64
# No parent found for E05003206 for the variable Unemployment rate - aged 16-64
# No parent found for E05003207 for the variable Unemployment rate - aged 16-64
# No parent found for E05003208 for the variable Unemployment rate - aged 16-64
# No parent found for E05003209 for the variable Unemployment rate - aged 16-64
# No parent found for E05003210 for the variable Unemployment rate - aged 16-64
# No parent found for E05003211 for the variable Unemployment rate - aged 16-64
# No parent found for E05003212 for the variable Unemployment rate - aged 16-64
# No parent found for E05003213 for the variable Unemployment rate - aged 16-64
# No parent found for E05003214 for the variable Unemployment rate - aged 16-64
# No parent found for E05003215 for the variable Unemployment rate - aged 16-64
# No parent found for E05003216 for the variable Unemployment rate - aged 16-64
# No parent found for E05003217 for the variable Unemployment rate - aged 16-64
# No parent found for E05003218 for the variable Unemployment rate - aged 16-64
# No parent found for E05003219 for the variable Unemployment rate - aged 16-64
# No parent found for E05003220 for the variable Unemployment rate - aged 16-64
# No parent found for E05003221 for the variable Unemployment rate - aged 16-64
# No parent found for E05003222 for the variable Unemployment rate - aged 16-64
# No parent found for E05003223 for the variable Unemployment rate - aged 16-64
# No parent found for E05003224 for the variable Unemployment rate - aged 16-64
# No parent found for E05003225 for the variable Unemployment rate - aged 16-64
# No parent found for E05003226 for the variable Unemployment rate - aged 16-64
# No parent found for E05003227 for the variable Unemployment rate - aged 16-64
# No parent found for E05003228 for the variable Unemployment rate - aged 16-64
# No parent found for E05003229 for the variable Unemployment rate - aged 16-64
# No parent found for E05003230 for the variable Unemployment rate - aged 16-64
# No parent found for E05003231 for the variable Unemployment rate - aged 16-64
# No parent found for E05003232 for the variable Unemployment rate - aged 16-64
# No parent found for E05003233 for the variable Unemployment rate - aged 16-64
# No parent found for E05003234 for the variable Unemployment rate - aged 16-64
# No parent found for E05006191 for the variable Unemployment rate - aged 16-64
# No parent found for E05006198 for the variable Unemployment rate - aged 16-64
# No parent found for E05006203 for the variable Unemployment rate - aged 16-64
# No parent found for E05006206 for the variable Unemployment rate - aged 16-64
# No parent found for E05006297 for the variable Unemployment rate - aged 16-64
# No parent found for E05006298 for the variable Unemployment rate - aged 16-64
# No parent found for E05006299 for the variable Unemployment rate - aged 16-64
# No parent found for E05006300 for the variable Unemployment rate - aged 16-64
# No parent found for E05006301 for the variable Unemployment rate - aged 16-64
# No parent found for E05006302 for the variable Unemployment rate - aged 16-64
# No parent found for E05006303 for the variable Unemployment rate - aged 16-64
# No parent found for E05006304 for the variable Unemployment rate - aged 16-64
# No parent found for E05006305 for the variable Unemployment rate - aged 16-64
# No parent found for E05006306 for the variable Unemployment rate - aged 16-64
# No parent found for E05006307 for the variable Unemployment rate - aged 16-64
# No parent found for E05006308 for the variable Unemployment rate - aged 16-64
# No parent found for E05006309 for the variable Unemployment rate - aged 16-64
# No parent found for E05006310 for the variable Unemployment rate - aged 16-64
# No parent found for E05006311 for the variable Unemployment rate - aged 16-64
# No parent found for E05006312 for the variable Unemployment rate - aged 16-64
# No parent found for E05006313 for the variable Unemployment rate - aged 16-64
# No parent found for E05006314 for the variable Unemployment rate - aged 16-64
# No parent found for E05006315 for the variable Unemployment rate - aged 16-64
# No parent found for E05006316 for the variable Unemployment rate - aged 16-64
# No parent found for E05009664 for the variable Unemployment rate - aged 16-64
# No parent found for E05009665 for the variable Unemployment rate - aged 16-64
# No parent found for E05009666 for the variable Unemployment rate - aged 16-64
# No parent found for E05009667 for the variable Unemployment rate - aged 16-64
# No parent found for E05009668 for the variable Unemployment rate - aged 16-64
# No parent found for E05009669 for the variable Unemployment rate - aged 16-64
# No parent found for E05009670 for the variable Unemployment rate - aged 16-64
# No parent found for E05009671 for the variable Unemployment rate - aged 16-64
# No parent found for E05009672 for the variable Unemployment rate - aged 16-64
# No parent found for E05009673 for the variable Unemployment rate - aged 16-64
# No parent found for E05009674 for the variable Unemployment rate - aged 16-64
# No parent found for E05009675 for the variable Unemployment rate - aged 16-64
# No parent found for E05009676 for the variable Unemployment rate - aged 16-64
# No parent found for E05009677 for the variable Unemployment rate - aged 16-64
# No parent found for E05009678 for the variable Unemployment rate - aged 16-64
# No parent found for E05009679 for the variable Unemployment rate - aged 16-64
# No parent found for E05009680 for the variable Unemployment rate - aged 16-64
# No parent found for E05009681 for the variable Unemployment rate - aged 16-64
# No parent found for E05009682 for the variable Unemployment rate - aged 16-64
# No parent found for E05009683 for the variable Unemployment rate - aged 16-64
# No parent found for E05009684 for the variable Unemployment rate - aged 16-64
# No parent found for E05009685 for the variable Unemployment rate - aged 16-64
# No parent found for E05009686 for the variable Unemployment rate - aged 16-64
# No parent found for E05009687 for the variable Unemployment rate - aged 16-64
# No parent found for E05009688 for the variable Unemployment rate - aged 16-64
# No parent found for E05010044 for the variable Unemployment rate - aged 16-64
# No parent found for E05010045 for the variable Unemployment rate - aged 16-64
# No parent found for E05010046 for the variable Unemployment rate - aged 16-64
# No parent found for E05010047 for the variable Unemployment rate - aged 16-64
# No parent found for E05010048 for the variable Unemployment rate - aged 16-64
# No parent found for E05010049 for the variable Unemployment rate - aged 16-64
# No parent found for E05010050 for the variable Unemployment rate - aged 16-64
# No parent found for E05010051 for the variable Unemployment rate - aged 16-64
# No parent found for E05010052 for the variable Unemployment rate - aged 16-64
# No parent found for E05010053 for the variable Unemployment rate - aged 16-64
# No parent found for E05010054 for the variable Unemployment rate - aged 16-64
# No parent found for E05010055 for the variable Unemployment rate - aged 16-64
# No parent found for E05010056 for the variable Unemployment rate - aged 16-64
# No parent found for E05010057 for the variable Unemployment rate - aged 16-64
# No parent found for E05010058 for the variable Unemployment rate - aged 16-64
# No parent found for E05010059 for the variable Unemployment rate - aged 16-64
# No parent found for E05010060 for the variable Unemployment rate - aged 16-64
# No parent found for E05010061 for the variable Unemployment rate - aged 16-64
# No parent found for E05010062 for the variable Unemployment rate - aged 16-64
# No parent found for E05010774 for the variable Unemployment rate - aged 16-64
# No parent found for E05010775 for the variable Unemployment rate - aged 16-64
# No parent found for E05010776 for the variable Unemployment rate - aged 16-64
# No parent found for E05010777 for the variable Unemployment rate - aged 16-64
# No parent found for E05010778 for the variable Unemployment rate - aged 16-64
# No parent found for E05010779 for the variable Unemployment rate - aged 16-64
# No parent found for E05010780 for the variable Unemployment rate - aged 16-64
# No parent found for E05011308 for the variable Unemployment rate - aged 16-64
# No parent found for E05011309 for the variable Unemployment rate - aged 16-64
# No parent found for E05011310 for the variable Unemployment rate - aged 16-64
# No parent found for E05011311 for the variable Unemployment rate - aged 16-64
# No parent found for E05011312 for the variable Unemployment rate - aged 16-64
# No parent found for E05011313 for the variable Unemployment rate - aged 16-64
# No parent found for E05011314 for the variable Unemployment rate - aged 16-64
# No parent found for E05011315 for the variable Unemployment rate - aged 16-64
# No parent found for E05011316 for the variable Unemployment rate - aged 16-64
# No parent found for E05011317 for the variable Unemployment rate - aged 16-64
# No parent found for E05011318 for the variable Unemployment rate - aged 16-64
# No parent found for E05011319 for the variable Unemployment rate - aged 16-64
# No parent found for E05011320 for the variable Unemployment rate - aged 16-64
# No parent found for E05011321 for the variable Unemployment rate - aged 16-64
# No parent found for E05011322 for the variable Unemployment rate - aged 16-64
# No parent found for E05011323 for the variable Unemployment rate - aged 16-64
# No parent found for E05011324 for the variable Unemployment rate - aged 16-64
# No parent found for E05011325 for the variable Unemployment rate - aged 16-64
# No parent found for E05011326 for the variable Unemployment rate - aged 16-64
# No parent found for E05011327 for the variable Unemployment rate - aged 16-64
# No parent found for E05011328 for the variable Unemployment rate - aged 16-64
# No parent found for E05011329 for the variable Unemployment rate - aged 16-64
# No parent found for E05011330 for the variable Unemployment rate - aged 16-64
# No parent found for E05011331 for the variable Unemployment rate - aged 16-64
# No parent found for E05011332 for the variable Unemployment rate - aged 16-64
# No parent found for E05011333 for the variable Unemployment rate - aged 16-64
# No parent found for E05011334 for the variable Unemployment rate - aged 16-64
# No parent found for E05011335 for the variable Unemployment rate - aged 16-64
# No parent found for E05011336 for the variable Unemployment rate - aged 16-64
# No parent found for E05011337 for the variable Unemployment rate - aged 16-64
# No parent found for E05011338 for the variable Unemployment rate - aged 16-64
# No parent found for E05011339 for the variable Unemployment rate - aged 16-64
# No parent found for E05011340 for the variable Unemployment rate - aged 16-64
# No parent found for E05011341 for the variable Unemployment rate - aged 16-64
# No parent found for E05011342 for the variable Unemployment rate - aged 16-64
# No parent found for E05011343 for the variable Unemployment rate - aged 16-64
# No parent found for E05011344 for the variable Unemployment rate - aged 16-64
# No parent found for E05011345 for the variable Unemployment rate - aged 16-64
# No parent found for E05011346 for the variable Unemployment rate - aged 16-64
# No parent found for E05011347 for the variable Unemployment rate - aged 16-64
# No parent found for E05011490 for the variable Unemployment rate - aged 16-64
# No parent found for E05011491 for the variable Unemployment rate - aged 16-64
# No parent found for E05011492 for the variable Unemployment rate - aged 16-64
# No parent found for E05011493 for the variable Unemployment rate - aged 16-64
# No parent found for E05011494 for the variable Unemployment rate - aged 16-64
# No parent found for E05011495 for the variable Unemployment rate - aged 16-64
# No parent found for E05011496 for the variable Unemployment rate - aged 16-64
# No parent found for E05011497 for the variable Unemployment rate - aged 16-64
# No parent found for E05011498 for the variable Unemployment rate - aged 16-64
# No parent found for E05011499 for the variable Unemployment rate - aged 16-64
# No parent found for E05011500 for the variable Unemployment rate - aged 16-64
# No parent found for E05011501 for the variable Unemployment rate - aged 16-64
# No parent found for E05011502 for the variable Unemployment rate - aged 16-64
# No parent found for E05011503 for the variable Unemployment rate - aged 16-64
# No parent found for E05011504 for the variable Unemployment rate - aged 16-64
# No parent found for E05011505 for the variable Unemployment rate - aged 16-64
# No parent found for E05011506 for the variable Unemployment rate - aged 16-64
# No parent found for E05011507 for the variable Unemployment rate - aged 16-64
# ...
# No parent found for E05009676 for the variable Proportion of households fuel poor (%)
# No parent found for E05009677 for the variable Proportion of households fuel poor (%)
# No parent found for E05009678 for the variable Proportion of households fuel poor (%)
# No parent found for E05009679 for the variable Proportion of households fuel poor (%)
# No parent found for E05009680 for the variable Proportion of households fuel poor (%)
# No parent found for E05009681 for the variable Proportion of households fuel poor (%)
# No parent found for E05009682 for the variable Proportion of households fuel poor (%)
# No parent found for E05009683 for the variable Proportion of households fuel poor (%)
# No parent found for E05009684 for the variable Proportion of households fuel poor (%)
# No parent found for E05009685 for the variable Proportion of households fuel poor (%)
# No parent found for E05009686 for the variable Proportion of households fuel poor (%)
# No parent found for E05009687 for the variable Proportion of households fuel poor (%)
# No parent found for E05009688 for the variable Proportion of households fuel poor (%)
# No parent found for E05010044 for the variable Proportion of households fuel poor (%)
# No parent found for E05010045 for the variable Proportion of households fuel poor (%)
# No parent found for E05010046 for the variable Proportion of households fuel poor (%)
# No parent found for E05010047 for the variable Proportion of households fuel poor (%)
# No parent found for E05010048 for the variable Proportion of households fuel poor (%)
# No parent found for E05010049 for the variable Proportion of households fuel poor (%)
# No parent found for E05010050 for the variable Proportion of households fuel poor (%)
# No parent found for E05010051 for the variable Proportion of households fuel poor (%)
# No parent found for E05010052 for the variable Proportion of households fuel poor (%)
# No parent found for E05010053 for the variable Proportion of households fuel poor (%)
# No parent found for E05010054 for the variable Proportion of households fuel poor (%)
# No parent found for E05010055 for the variable Proportion of households fuel poor (%)
# No parent found for E05010056 for the variable Proportion of households fuel poor (%)
# No parent found for E05010057 for the variable Proportion of households fuel poor (%)
# No parent found for E05010058 for the variable Proportion of households fuel poor (%)
# No parent found for E05010059 for the variable Proportion of households fuel poor (%)
# No parent found for E05010060 for the variable Proportion of households fuel poor (%)
# No parent found for E05010061 for the variable Proportion of households fuel poor (%)
# No parent found for E05010062 for the variable Proportion of households fuel poor (%)
# No parent found for E05010774 for the variable Proportion of households fuel poor (%)
# No parent found for E05010775 for the variable Proportion of households fuel poor (%)
# No parent found for E05010776 for the variable Proportion of households fuel poor (%)
# No parent found for E05010777 for the variable Proportion of households fuel poor (%)
# No parent found for E05010778 for the variable Proportion of households fuel poor (%)
# No parent found for E05010779 for the variable Proportion of households fuel poor (%)
# No parent found for E05010780 for the variable Proportion of households fuel poor (%)
# No parent found for E05011308 for the variable Proportion of households fuel poor (%)
# No parent found for E05011309 for the variable Proportion of households fuel poor (%)
# No parent found for E05011310 for the variable Proportion of households fuel poor (%)
# No parent found for E05011311 for the variable Proportion of households fuel poor (%)
# No parent found for E05011312 for the variable Proportion of households fuel poor (%)
# No parent found for E05011313 for the variable Proportion of households fuel poor (%)
# No parent found for E05011314 for the variable Proportion of households fuel poor (%)
# No parent found for E05011315 for the variable Proportion of households fuel poor (%)
# No parent found for E05011316 for the variable Proportion of households fuel poor (%)
# No parent found for E05011317 for the variable Proportion of households fuel poor (%)
# No parent found for E05011318 for the variable Proportion of households fuel poor (%)
# No parent found for E05011319 for the variable Proportion of households fuel poor (%)
# No parent found for E05011320 for the variable Proportion of households fuel poor (%)
# No parent found for E05011321 for the variable Proportion of households fuel poor (%)
# No parent found for E05011322 for the variable Proportion of households fuel poor (%)
# No parent found for E05011323 for the variable Proportion of households fuel poor (%)
# No parent found for E05011324 for the variable Proportion of households fuel poor (%)
# No parent found for E05011325 for the variable Proportion of households fuel poor (%)
# No parent found for E05011326 for the variable Proportion of households fuel poor (%)
# No parent found for E05011327 for the variable Proportion of households fuel poor (%)
# No parent found for E05011328 for the variable Proportion of households fuel poor (%)
# No parent found for E05011329 for the variable Proportion of households fuel poor (%)
# No parent found for E05011330 for the variable Proportion of households fuel poor (%)
# No parent found for E05011331 for the variable Proportion of households fuel poor (%)
# No parent found for E05011332 for the variable Proportion of households fuel poor (%)
# No parent found for E05011333 for the variable Proportion of households fuel poor (%)
# No parent found for E05011334 for the variable Proportion of households fuel poor (%)
# No parent found for E05011335 for the variable Proportion of households fuel poor (%)
# No parent found for E05011336 for the variable Proportion of households fuel poor (%)
# No parent found for E05011337 for the variable Proportion of households fuel poor (%)
# No parent found for E05011338 for the variable Proportion of households fuel poor (%)
# No parent found for E05011339 for the variable Proportion of households fuel poor (%)
# No parent found for E05011340 for the variable Proportion of households fuel poor (%)
# No parent found for E05011341 for the variable Proportion of households fuel poor (%)
# No parent found for E05011342 for the variable Proportion of households fuel poor (%)
# No parent found for E05011343 for the variable Proportion of households fuel poor (%)
# No parent found for E05011344 for the variable Proportion of households fuel poor (%)
# No parent found for E05011345 for the variable Proportion of households fuel poor (%)
# No parent found for E05011346 for the variable Proportion of households fuel poor (%)
# No parent found for E05011347 for the variable Proportion of households fuel poor (%)
# No parent found for E05011490 for the variable Proportion of households fuel poor (%)
# No parent found for E05011491 for the variable Proportion of households fuel poor (%)
# No parent found for E05011492 for the variable Proportion of households fuel poor (%)
# No parent found for E05011493 for the variable Proportion of households fuel poor (%)
# No parent found for E05011494 for the variable Proportion of households fuel poor (%)
# No parent found for E05011495 for the variable Proportion of households fuel poor (%)
# No parent found for E05011496 for the variable Proportion of households fuel poor (%)
# No parent found for E05011497 for the variable Proportion of households fuel poor (%)
# No parent found for E05011498 for the variable Proportion of households fuel poor (%)
# No parent found for E05011499 for the variable Proportion of households fuel poor (%)
# No parent found for E05011500 for the variable Proportion of households fuel poor (%)
# No parent found for E05011501 for the variable Proportion of households fuel poor (%)
# No parent found for E05011502 for the variable Proportion of households fuel poor (%)
# No parent found for E05011503 for the variable Proportion of households fuel poor (%)
# No parent found for E05011504 for the variable Proportion of households fuel poor (%)
# No parent found for E05011505 for the variable Proportion of households fuel poor (%)
# No parent found for E05011506 for the variable Proportion of households fuel poor (%)
# No parent found for E05011507 for the variable Proportion of households fuel poor (%)
# No parent found for E05011720 for the variable Proportion of households fuel poor (%)
# No parent found for E05011721 for the variable Proportion of households fuel poor (%)
# No parent found for E05011722 for the variable Proportion of households fuel poor (%)
# No parent found for E05011723 for the variable Proportion of households fuel poor (%)
# No parent found for E05011724 for the variable Proportion of households fuel poor (%)
# No parent found for E05011725 for the variable Proportion of households fuel poor (%)
# No parent found for E05011726 for the variable Proportion of households fuel poor (%)
# No parent found for E05011727 for the variable Proportion of households fuel poor (%)
# No parent found for E05011728 for the variable Proportion of households fuel poor (%)
# No parent found for E05011729 for the variable Proportion of households fuel poor (%)
# No parent found for E05011730 for the variable Proportion of households fuel poor (%)
# No parent found for E05011731 for the variable Proportion of households fuel poor (%)
# No parent found for E05011732 for the variable Proportion of households fuel poor (%)
# No parent found for E05011733 for the variable Proportion of households fuel poor (%)
# No parent found for E05011734 for the variable Proportion of households fuel poor (%)
# No parent found for E05011735 for the variable Proportion of households fuel poor (%)
# No parent found for E05011736 for the variable Proportion of households fuel poor (%)
# No parent found for E05011737 for the variable Proportion of households fuel poor (%)
# No parent found for E05011738 for the variable Proportion of households fuel poor (%)
# No parent found for E05011739 for the variable Proportion of households fuel poor (%)
# No parent found for E05011740 for the variable Proportion of households fuel poor (%)
# No parent found for E05011741 for the variable Proportion of households fuel poor (%)
# No parent found for E05011742 for the variable Proportion of households fuel poor (%)
# No parent found for E05012356 for the variable Proportion of households fuel poor (%)
# No parent found for E05012357 for the variable Proportion of households fuel poor (%)
# No parent found for E05012358 for the variable Proportion of households fuel poor (%)
# No parent found for E05012359 for the variable Proportion of households fuel poor (%)
# No parent found for E05012360 for the variable Proportion of households fuel poor (%)
# No parent found for E05012361 for the variable Proportion of households fuel poor (%)
# No parent found for E05012362 for the variable Proportion of households fuel poor (%)
# No parent found for E05012363 for the variable Proportion of households fuel poor (%)
# No parent found for E05012364 for the variable Proportion of households fuel poor (%)
# No parent found for E05012365 for the variable Proportion of households fuel poor (%)
# No parent found for E05012366 for the variable Proportion of households fuel poor (%)
# No parent found for E05012367 for the variable Proportion of households fuel poor (%)
# No parent found for E05012368 for the variable Proportion of households fuel poor (%)
# No parent found for E05012369 for the variable Proportion of households fuel poor (%)
# No parent found for E05012370 for the variable Proportion of households fuel poor (%)
# No parent found for E05012371 for the variable Proportion of households fuel poor (%)
# No parent found for E05012372 for the variable Proportion of households fuel poor (%)
# No parent found for E05012373 for the variable Proportion of households fuel poor (%)
# No parent found for E05012374 for the variable Proportion of households fuel poor (%)
# No parent found for E05012375 for the variable Proportion of households fuel poor (%)
# No parent found for E05012376 for the variable Proportion of households fuel poor (%)
# No parent found for E05012377 for the variable Proportion of households fuel poor (%)
# No parent found for E05012378 for the variable Proportion of households fuel poor (%)
# No parent found for E05012379 for the variable Proportion of households fuel poor (%)
# No parent found for E05012380 for the variable Proportion of households fuel poor (%)
# No parent found for E05012381 for the variable Proportion of households fuel poor (%)
# No parent found for E05012382 for the variable Proportion of households fuel poor (%)
# No parent found for E05012383 for the variable Proportion of households fuel poor (%)
# No parent found for E05012384 for the variable Proportion of households fuel poor (%)
# No parent found for E05012385 for the variable Proportion of households fuel poor (%)
# No parent found for E05012386 for the variable Proportion of households fuel poor (%)
# No parent found for E05012387 for the variable Proportion of households fuel poor (%)
# No parent found for E05012388 for the variable Proportion of households fuel poor (%)
# No parent found for E05012389 for the variable Proportion of households fuel poor (%)
# No parent found for E05012390 for the variable Proportion of households fuel poor (%)
# No parent found for E05012391 for the variable Proportion of households fuel poor (%)
# No parent found for E05012548 for the variable Proportion of households fuel poor (%)
# No parent found for E05012549 for the variable Proportion of households fuel poor (%)
# No parent found for E05012550 for the variable Proportion of households fuel poor (%)
# No parent found for E05012551 for the variable Proportion of households fuel poor (%)
# No parent found for E05012552 for the variable Proportion of households fuel poor (%)
# No parent found for E05012553 for the variable Proportion of households fuel poor (%)
# No parent found for E05012554 for the variable Proportion of households fuel poor (%)
# No parent found for E05012555 for the variable Proportion of households fuel poor (%)
# No parent found for E05012556 for the variable Proportion of households fuel poor (%)
# No parent found for E05012557 for the variable Proportion of households fuel poor (%)
# No parent found for E05012558 for the variable Proportion of households fuel poor (%)
# No parent found for E05012559 for the variable Proportion of households fuel poor (%)
# No parent found for E05012560 for the variable Proportion of households fuel poor (%)
# No parent found for E05012561 for the variable Proportion of households fuel poor (%)
# No parent found for E05012562 for the variable Proportion of households fuel poor (%)
# No parent found for E05012563 for the variable Proportion of households fuel poor (%)
# No parent found for E05012564 for the variable Proportion of households fuel poor (%)
# No parent found for E05012940 for the variable Proportion of households fuel poor (%)
# No parent found for E05012941 for the variable Proportion of households fuel poor (%)
# No parent found for E05012942 for the variable Proportion of households fuel poor (%)
# No parent found for E05012943 for the variable Proportion of households fuel poor (%)
# No parent found for E05012944 for the variable Proportion of households fuel poor (%)
# No parent found for E05012945 for the variable Proportion of households fuel poor (%)
# No parent found for E05012946 for the variable Proportion of households fuel poor (%)
# No parent found for E05012947 for the variable Proportion of households fuel poor (%)
# No parent found for E05012948 for the variable Proportion of households fuel poor (%)
# No parent found for E05012949 for the variable Proportion of households fuel poor (%)
# No parent found for E05012950 for the variable Proportion of households fuel poor (%)
# No parent found for E05012951 for the variable Proportion of households fuel poor (%)
# No parent found for E05012952 for the variable Proportion of households fuel poor (%)

# %%
def which_variables(data):
    input_variables = data.apply(lambda x: x.dropna().index.to_list(), axis=1)
    return input_variables
input_variables = which_variables(data)

# %%
# Normalise and show the result
data = normalise(data, [True, True, False, False, True, True])

# Add the input variables and map them to the code.
data['input_variables'] = input_variables
data['input_variables'] = data['input_variables'].apply(lambda x: [variable_key.get(item, item) for item in x])

# %%
code_to_name = pd.read_csv('data/geo/geography_code_name_only.csv')
code_to_name.rename(columns={'code':'geography_code', 'name': 'geography_name'}, inplace=True)
data = data.merge(code_to_name, on='geography_code').set_index('geography_code')
data[['mean_normalised_score', 'input_variables']].head()
# Out:
#                 mean_normalised_score     input_variables
# geography_code
# E06000001                    0.551879  [1, 2, 3, 4, 5, 6]
# E06000002                    0.679635  [1, 2, 3, 4, 5, 6]
# E06000003                    0.562172  [1, 2, 3, 4, 5, 6]
# E06000004                    0.416625  [1, 2, 3, 4, 5, 6]
# E06000005                    0.394855  [1, 2, 3, 4, 5, 6]

# %%
data[['mean_normalised_score', 'input_variables', 'geography_name']].to_csv('playground/modelling/economic_insecurity.csv')
